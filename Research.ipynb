# %% [markdown]
# <a href="https://colab.research.google.com/github/kalijauhari/research/blob/main/Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset1 = pd.read_csv("https://raw.githubusercontent.com/kalijauhari/research/main/data/Laptop-ACOS/laptop_quad_dev.tsv",on_bad_lines='skip' )

# %%
dataset1.head(10)
# Out:
#             this unit is ` ` pretty ` ` and stylish   \
# 0  for now i ' m okay with upping the experience ...
# 1                       seems unlikely but whatever
# 2  this version has been my least favorite versio...
# 3     - biggest disappointment is the track pad .\t5
# 4          should not of bought this chromebook .\t5
# 5  after about 5 / 10 minutes of use the screen g...
# 6  i can not stand the trackpad or the keyboard k...
# 7  the keyboard is stiff and unresponsive to my t...
# 8  the chromebook r 11 was hardly used and only a...
# 9           one day it just would not power up .\t-1
#
#    so my high school daughter was attracted to it for that reason .\t1  \
# 0                             12 LAPTOP#GENERAL 1 -1
# 1                            i ' ll go with it .\t-1
# 2                               8 LAPTOP#GENERAL 0 5
# 3                             7 HARDWARE#GENERAL 0 2
# 4                              6 LAPTOP#GENERAL 0 -1
# ...

# %%
dataset2 = pd.read_csv("https://raw.githubusercontent.com/kalijauhari/research/main/data/Restaurant-ACOS/rest16_quad_dev.tsv" ,on_bad_lines='skip')

# %%
dataset2.head(10)
# Out:
#                                                                                                                                                                                     ca n ' t wait wait for my next visit .\t-1  \
# their sake list was extensive                       but we were looking for purple haze                which was n ' t listed but made for us upon re... 3 DRINKS#STYLE_OPTIONS 2 4                                      5\t-1
# the spicy tuna roll was unusually good and the ...  great appetizer to share !\t1                     4 FOOD#QUALITY 2 6                                 7\t9                                             12 FOOD#QUALITY 2 13
# we love th pink pony .\t3                          5 RESTAURANT#GENERAL 2 1                           2                                                  NaN                                                               NaN
# ...

# %%
# NLTK
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
nltk.download('stopwords')

#Spacy
import spacy
nlp = spacy.load('en_core_web_sm')

# Other
import re
import json
import string
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

#Keras
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Activation
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#load data
import pandas as pd
reviews_train = pd.read_csv("https://raw.githubusercontent.com/kalijauhari/research/main/data/Restaurant-ACOS/rest16_quad_test.tsv" ,on_bad_lines='skip')

#show first 5 records
reviews_train.head()
# Out:
#                                            yum !\t-1  \
# 0                      serves really good sushi .\t3
# 1              green tea creme brulee is a must !\t0
# 2  the entire staff was extremely accomodating an...
# 3  i ' ve been to this restaurant over a dozen ti...
# 4  the owner is belligerent to guests that have a...
#
#          -1 FOOD#QUALITY 2 0   1
# 0         4 FOOD#QUALITY 2 2   3
# 1         4 FOOD#QUALITY 2 6   7
# 2      3 SERVICE#GENERAL 2 5   6
# 3  7 RESTAURANT#GENERAL 2 12  14
# 4      2 SERVICE#GENERAL 0 3   4

# %%
reviews_train.columns =  ['review', 'aspect_category', 'sent']
reviews_train
# Out:
#                                                 review  \
# 0                        serves really good sushi .\t3
# 1                green tea creme brulee is a must !\t0
# 2    the entire staff was extremely accomodating an...
# 3    i ' ve been to this restaurant over a dozen ti...
# 4    the owner is belligerent to guests that have a...
# ..                                                 ...
# 279  i felt ackward and next time went to the casin...
# 280                            this place rocks ! !\t1
# 281                         insultingly overpriced\t-1
# 282                    - mediocre service / quality\t2
# 283  two rascally kids were seated near us for the ...
#
#                       aspect_category  sent
# 0                  4 FOOD#QUALITY 2 2     3
# 1                  4 FOOD#QUALITY 2 6     7
# 2               3 SERVICE#GENERAL 2 5     6
# 3           7 RESTAURANT#GENERAL 2 12    14
# 4               2 SERVICE#GENERAL 0 3     4
# ...

# %%
# reviews_train.columns
print(reviews_train.groupby('aspect_category').size().sort_values(ascending=False))

#how many categories
print("number of categories",reviews_train.aspect_category.nunique())
# Out:
# aspect_category
# -1 RESTAURANT#GENERAL 2 -1    16
# -1 RESTAURANT#GENERAL 2 0     11
# -1 SERVICE#GENERAL 0 -1       10
# -1 RESTAURANT#GENERAL 0 -1     9
# -1 FOOD#QUALITY 2 0            7
#                               ..
# 14 SERVICE#GENERAL 0 12        1
# 15 FOOD#QUALITY 0 18           1
# 15 FOOD#QUALITY 2 -1           1
# 15 FOOD#QUALITY 2 8            1
# 9 SERVICE#GENERAL 1 -1         1
# Length: 182, dtype: int64
# number of categories 182

# %%
absa_model = Sequential()
absa_model.add(Dense(512, input_shape=(6000,), activation='relu'))
absa_model.add((Dense(256, activation='relu')))
absa_model.add((Dense(128, activation='relu')))
absa_model.add(Dense(13, activation='softmax'))
#compile model
absa_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from nltk.tokenize import tokenize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-78cdd555193a> in <module>
# ----> 1 from nltk.tokenize import tokenize
#
# ImportError: cannot import name 'tokenize' from 'nltk.tokenize' (/usr/local/lib/python3.9/dist-packages/nltk/tokenize/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
pip install tokenizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 KB 8.8 MB/s eta 0:00:00
# ...

# %%
import tokenizer

# %%
vocab_size = 6000 # We set a maximum size for the vocabulary
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(reviews_train.review)
reviews_tokenized = pd.DataFrame(tokenizer.texts_to_matrix(reviews_train.review))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-24e5ae374c4b> in <module>
#       1 vocab_size = 6000 # We set a maximum size for the vocabulary
# ----> 2 tokenizer = Tokenizer(num_words=vocab_size)
#       3 tokenizer.fit_on_texts(reviews_train.review)
#       4 reviews_tokenized = pd.DataFrame(tokenizer.texts_to_matrix(reviews_train.review))
#
# NameError: name 'Tokenizer' is not defined
